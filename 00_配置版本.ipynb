# %% [markdown]
# # 配置版本

# %% [markdown]
# # 1. 安装 Python 版本

# %% [markdown]
# ① 首先打开 Anaconda 的 Prompt 终端，输入 jupyter kernelspec list，查看已经安装的 python 版本。如下图所示，Anaconda 只有自带的 python3。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ② 输入 conda create --name py3.6.3 python=3.6.3 命令，输入 [y]/n 时输入 y，创建 py3.6.3 虚拟环境，它会安装 python3.6.3 到 anaconda3 的 env 目录下。( 注意：不要挂 VNP。)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ③ 首先确保目前盘和要进入的盘一样，输入 cd D:\11_Anaconda\envs\py3.6.3\Scripts 命令，进入 py3.6.3 目录下的 Scripts 文件夹下。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ④ 输入 conda activate py3.6.3 激活 py3.6.3环境后，再输入 pip install ipykernel 命令，会在 script 目录下会生成一系列工具，如下图所示。( 注意：不要挂 VNP。)

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ⑤ 将 Anaconda 文件夹下的 share/jupyter/kernels 文件夹中已经存在的项目复制一份，重命名为 python3.6.3。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ⑥ 打开文件夹中 json 文件，将 Python 3 改为 Python 3.6.3，如下图所示。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ⑦ 再次打开 Anaconda 终端，输入 jupyter kernelspec list，可以查看到已成功安上 Python3.6.3 的虚拟环境。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ⑧ 再次打开 Jupyter notebook，New 里面有 Python3.6.3 选项。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ⑨ 在 Jupyter notebook 中，用 python 代码打印 python 版本。

# %%
import sys
print(sys.version)
# Out:
# 3.6.3 |Anaconda, Inc.| (default, Nov  8 2017, 15:10:56) [MSC v.1900 64 bit (AMD64)]

# %% [markdown]
# # 2. 安装 opencv 版本

# %% [markdown]
# ① 再次打开一个Anaconda Prompt的终端，输入 conda activate py3.6.3，激活 Python3.6.3 环境，如下图所示。
#
# ② 使得需要进入的盘与当前盘一致，如下图所示。
#
# ③ 进入 py3.6.3 目录下。
#
# ④ 输入 pip install opencv-python==3.4.1.15 -i https://pypi.tuna.tsinghua.edu.cn/simple 下载 opencv 3.4.1.15，如下图所示。
#
# ⑤ 输入 pip install opencv-contrib-python==3.4.1.15 -i https://pypi.tuna.tsinghua.edu.cn/simple 下载 opencv-contrib 3.4.1.15，如下图所示。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ⑥ 输入 pip list 命令，可以发现确实已经安装上 opencv 3.4.1.15 和 opencv-contrib 3.4.1.15。

# %% [markdown]
# ![image.png](attachment:image.png)

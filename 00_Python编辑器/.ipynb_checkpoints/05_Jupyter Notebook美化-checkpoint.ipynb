# %% [markdown]
# # Jupyter Notebook美化

# %% [markdown]
# # 1. 背景字体美化

# %% [markdown]
# ## 1.1 设置背景字体

# %% [markdown]
# ① 将 Jupyter Notebook 背景美化，由 "惨白" 变成 "黑底"。
#
# ② 将 Jupyter 的字体进行美化。
#
# ③ 实现效果，如下图所示。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ④ 快捷命令：jt -t onedork -f roboto -fs 14 -nfs 14 -tfs 14 -ofs 11
#
# 参考链接：https://cloud.tencent.com/developer/article/1358591

# %% [markdown]
# ## 1.2 恢复原来配置

# %% [markdown]
# ① 在Anaconda中输入 jt -r 会恢复到原来的配置。

# %% [markdown]
# # 2. 配置目录

# %% [markdown]
# ① 设置目录可以使得笔记更有层次，并且方便通过目录跳转到相应的知识点。
#
# ② 下图为有目录的笔记，可以通过左侧目录进行跳转。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ③ 下图为没有目录的笔记，必须手动翻页，翻到相应的知识点。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 参考链接：https://zhuanlan.zhihu.com/p/350390959

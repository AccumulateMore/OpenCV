# %% [markdown]
# # Jupyter Notebook代码文件

# %% [markdown]
# # 1. 默认C盘

# %% [markdown]
# ① Jupyter Notebook 默认打开的是C盘，如图所示。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. 其余的盘

# %% [markdown]
# ① 当 Jupyter Notebook 需要打开其他盘的时候，首先需要打开Anaconda Prompt。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ② 然后在 Anaconda Prompt 中输入D: (任意盘F、G都可以，记得后面加冒号)。
#
# ③ 最后输入 Jupyter Notebook，最后把链接复制到浏览器中，就可以进入任意盘中，显示该盘的文件夹、文件。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. 创建代码文件

# %% [markdown]
# ① 若想代码保存在某一个文件夹中，就点击要进入的文件夹，进入想要进入的文件夹中。也可以不保存在文件夹中，仅保存在某盘中。
#
# ② 确定代码文件放置的位置后，点击 new，再点击 Python3，即可创建运行代码的文件，如下图所示。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ③ 在输入代码的地方写代码，如下图所示。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. 打开代码文件

# %% [markdown]
# ① 进入已经保存代码文件的目录下，可以看到该文件下所有的代码文件。
#
# ② 点击需要打开的代码，即可进入代码文件。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ③ 进入代码文件后，可以继续写代码、写笔记。

# %% [markdown]
# ![image.png](attachment:image.png)
